# %% [markdown]
# # Social Graph Analysis Group Project
#
# ### Grandma’s Cookbook, Lookbook: An Analysis of Ingredients Association With Ethnic Cuisines
#
# #### Group Members:
# * Nick Potts
# * Kristi Conry
# * Jacob Lebowitz
# * Anthony Bryson

# %% [markdown]
# ### Possible Goals :)
#
# 1) Predict popular cuisine's based on what ingediants you have <br>
# 2) Essential ingrediants if you like a favorite cuisine <br>
# 3) Ingrediant recommendation system ( if you lke 3 types of cuisine find top similar ingrediants )
#
# ### Just some questions for our data :)
#
# 1) Which cuisine's are most similar based on ingediants? and why?

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

import json
import collections
import re
import pickle

import nltk
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords, wordnet
from nltk.stem import PorterStemmer, WordNetLemmatizer

# %%
df = pd.read_json('data/train.json')

# %%
df.info()

# %%
df.head(5)

# %%
df['ingredients_sentence'] = df['ingredients'].apply(lambda x: ' '.join(x))

# %%
df.head()

# %%
def clean_ingredients(text):    
    #Remove punctuations
    text=re.sub(r'[^\w\s]','',text)
    
    #Remove Digits
    text=re.sub(r"(\d)", "", text)
    
    #Remove content inside paranthesis
    text=re.sub(r'\([^)]*\)', '', text)
    
    #Remove Brand Name
    text=re.sub(u'\w*\u2122', '', text)
    
    #Convert to lowercase
    text=text.lower()
    
    #Remove Stop Words
    stop_words = set(stopwords.words('english'))
    word_tokens = word_tokenize(text)
    filtered_sentence = [w for w in word_tokens if not w in stop_words]
    filtered_sentence = []
    for w in word_tokens:
        if w not in stop_words:
            filtered_sentence.append(w)
    text=' '.join(filtered_sentence)
        
    
    #Porter Stemmer Algorithm
    words = word_tokenize(text)
    word_ps=[]
    for w in words:
        word_ps.append(ps.stem(w))
    text=' '.join(word_ps)
    
    return text

# %%
ps = PorterStemmer()

result = []

for s in df['ingredients']:
    
    l=[]
    
    for x in s:
    
        cleaned_text = clean_ingredients(x) 
    
        l.append(cleaned_text)
    
        
    result.append(l)
    
print(result[:5])
# Out:
# [['romain lettuc', 'black oliv', 'grape tomato', 'garlic', 'pepper', 'purpl onion', 'season', 'garbanzo bean', 'feta chees crumbl'], ['plain flour', 'ground pepper', 'salt', 'tomato', 'ground black pepper', 'thyme', 'egg', 'green tomato', 'yellow corn meal', 'milk', 'veget oil'], ['egg', 'pepper', 'salt', 'mayonais', 'cook oil', 'green chili', 'grill chicken breast', 'garlic powder', 'yellow onion', 'soy sauc', 'butter', 'chicken liver'], ['water', 'veget oil', 'wheat', 'salt'], ['black pepper', 'shallot', 'cornflour', 'cayenn pepper', 'onion', 'garlic past', 'milk', 'butter', 'salt', 'lemon juic', 'water', 'chili powder', 'passata', 'oil', 'ground cumin', 'boneless chicken skinless thigh', 'garam masala', 'doubl cream', 'natur yogurt', 'bay leaf']]

# %%
df['ingredient_list_cleaned']=result

# %%
ps = PorterStemmer()

l=[]

for s in df['ingredients_sentence']:
    
    cleaned_text = clean_ingredients(s) 
    
    l.append(cleaned_text)
    
df['ingredient_cleaned']=l
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-3561885c9388> in <module>
# ----> 1 ps = PorterStemmer()
#       2
#       3 l=[]
#       4
#       5 for s in df['ingredients_sentence']:
#
# NameError: name 'PorterStemmer' is not defined

# %%
#df.to_csv('cleaned_data.csv', index=False)

# %%
cleaned_df = pd.read_csv('data/cleaned_data.csv')

# %%
cleaned_df.head()
# Out:
#       id      cuisine                                        ingredients  \
# 0  10259        greek  ['romaine lettuce', 'black olives', 'grape tom...
# 1  25693  southern_us  ['plain flour', 'ground pepper', 'salt', 'toma...
# 2  20130     filipino  ['eggs', 'pepper', 'salt', 'mayonaise', 'cooki...
# 3  22213       indian        ['water', 'vegetable oil', 'wheat', 'salt']
# 4  13162       indian  ['black pepper', 'shallots', 'cornflour', 'cay...
#
#                                 ingredients_sentence  \
# 0  romaine lettuce black olives grape tomatoes ga...
# 1  plain flour ground pepper salt tomatoes ground...
# 2  eggs pepper salt mayonaise cooking oil green c...
# 3                     water vegetable oil wheat salt
# 4  black pepper shallots cornflour cayenne pepper...
#
#                              ingredient_list_cleaned  \
# 0  ['romain lettuc', 'black oliv', 'grape tomato'...
# 1  ['plain flour', 'ground pepper', 'salt', 'toma...
# 2  ['egg', 'pepper', 'salt', 'mayonais', 'cook oi...
# 3            ['water', 'veget oil', 'wheat', 'salt']
# 4  ['black pepper', 'shallot', 'cornflour', 'caye...
#
#                                   ingredient_cleaned
# 0  romain lettuc black oliv grape tomato garlic p...
# 1  plain flour ground pepper salt tomato ground b...
# 2  egg pepper salt mayonais cook oil green chili ...
# 3                         water veget oil wheat salt
# 4  black pepper shallot cornflour cayenn pepper o...

# %%
cleaned_df['cuisine'].value_counts()
# Out:
# italian         7838
# mexican         6438
# southern_us     4320
# indian          3003
# chinese         2673
# french          2646
# cajun_creole    1546
# thai            1539
# japanese        1423
# greek           1175
# spanish          989
# korean           830
# vietnamese       825
# moroccan         821
# british          804
# filipino         755
# irish            667
# jamaican         526
# russian          489
# brazilian        467
# Name: cuisine, dtype: int64

# %%
real_ingredients = []

for ingredients in df['ingredient_list_cleaned']:
    for ingredient in ingredients:
        real_ingredients.append(ingredient.strip())
        
count_of_ingredient = collections.Counter(real_ingredients)
count_of_ingredient.most_common(10)
# Out:
# [('salt', 18049),
#  ('onion', 7972),
#  ('oliv oil', 7972),
#  ('water', 7457),
#  ('garlic', 7380),
#  ('sugar', 6434),
#  ('garlic clove', 6237),
#  ('butter', 4848),
#  ('ground black pepper', 4785),
#  ('allpurpos flour', 4632)]

# %%
fig = plt.figure(figsize=[10,6])

plt.xticks(rotation=70)

sns.countplot(cleaned_df['cuisine'])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='cuisine', ylabel='count'>

# %%
fig = plt.figure(figsize=[10,6])

plt.xticks(rotation=70)

sns.countplot(cleaned_df['cuisine'])

# %%
count_of_ingredient_ordered = sorted(count_of_ingredient.items(), key=lambda x: x[1], reverse=True)

count_of_ingredient_ordered
# Out:
# [('salt', 18049),
#  ('onion', 7972),
#  ('oliv oil', 7972),
#  ('water', 7457),
#  ('garlic', 7380),
#  ('sugar', 6434),
#  ('garlic clove', 6237),
#  ('butter', 4848),
#  ('ground black pepper', 4785),
#  ('allpurpos flour', 4632),
#  ('pepper', 4438),
#  ('veget oil', 4385),
#  ('egg', 3388),
#  ('soy sauc', 3296),
#  ('kosher salt', 3113),
#  ('green onion', 3078),
#  ('tomato', 3058),
#  ('larg egg', 2948),
#  ('carrot', 2814),
#  ('unsalt butter', 2782),
#  ('ground cumin', 2747),
#  ('extravirgin oliv oil', 2747),
#  ('black pepper', 2627),
#  ('milk', 2263),
#  ('chili powder', 2036),
#  ('oil', 1970),
#  ('red bell pepper', 1939),
#  ('purpl onion', 1896),
#  ('scallion', 1891),
#  ('grate parmesan chees', 1886),
#  ('sesam oil', 1773),
#  ('corn starch', 1757),
#  ('ginger', 1755),
#  ('bake powder', 1738),
#  ('jalapeno chili', 1730),
#  ('dri oregano', 1707),
#  ('chop cilantro fresh', 1698),
#  ('fresh lemon juic', 1679),
#  ('dice tomato', 1624),
#  ('fresh parsley', 1604),
#  ('minc garlic', 1583),
#  ('chicken broth', 1554),
#  ('sour cream', 1539),
#  ('cayenn pepper', 1523),
#  ('fresh ginger', 1503),
#  ('brown sugar', 1503),
#  ('cook spray', 1490),
#  ('shallot', 1477),
#  ('garlic powder', 1442),
#  ('lime', 1439),
#  ('lemon juic', 1395),
#  ('fresh lime juic', 1368),
#  ('flour', 1348),
#  ('honey', 1299),
#  ('vanilla extract', 1298),
#  ('paprika', 1287),
#  ('chop onion', 1251),
#  ('fish sauc', 1247),
#  ('ground cinnamon', 1231),
#  ('avocado', 1229),
#  ('canola oil', 1223),
#  ('dri white wine', 1218),
#  ('lemon', 1218),
#  ('rice vinegar', 1204),
#  ('yellow onion', 1184),
#  ('green bell pepper', 1180),
#  ('cilantro leav', 1160),
#  ('tomato past', 1158),
#  ('boneless skinless chicken breast', 1147),
#  ('heavi cream', 1146),
#  ('cilantro', 1142),
#  ('fresh basil', 1137),
#  ('flat leaf parsley', 1094),
#  ('white sugar', 1093),
#  ('lime juic', 1072),
#  ('chicken stock', 1039),
#  ('bay leav', 1036),
#  ('potato', 1018),
#  ('chicken', 982),
#  ('corn tortilla', 965),
#  ('salsa', 963),
#  ('cumin', 953),
#  ('freshli ground pepper', 949),
#  ('ground turmer', 949),
#  ('bake soda', 942),
#  ('sea salt', 940),
#  ('cumin seed', 935),
#  ('garam masala', 925),
#  ('shrimp', 912),
#  ('black bean', 896),
#  ('zucchini', 892),
#  ('ground beef', 878),
#  ('larg garlic clove', 873),
#  ('dri thyme', 873),
#  ('flour tortilla', 865),
#  ('tomato sauc', 865),
#  ('buttermilk', 863),
#  ('plum tomato', 858),
#  ('coconut milk', 854),
#  ('granul sugar', 849),
#  ('fresh cilantro', 841),
#  ('bay leaf', 839),
#  ('celeri', 837),
#  ('crush red pepper', 825),
#  ('chop cilantro', 796),
#  ('chicken breast', 793),
#  ('mayonais', 781),
#  ('shred cheddar chees', 769),
#  ('green chili', 768),
#  ('ground coriand', 768),
#  ('cucumb', 768),
#  ('whole milk', 764),
#  ('red wine vinegar', 752),
#  ('tumer', 738),
#  ('whip cream', 722),
#  ('cinnamon', 696),
#  ('curri powder', 694),
#  ('worcestershir sauc', 688),
#  ('white onion', 684),
#  ('ground ginger', 678),
#  ('sesam seed', 676),
#  ('hot sauc', 674),
#  ('red pepper flake', 669),
#  ('cinnamon stick', 646),
#  ('red chili pepper', 644),
#  ('bacon', 620),
#  ('boneless skinless chicken breast halv', 618),
#  ('peanut oil', 610),
#  ('ground nutmeg', 605),
#  ('clove', 600),
#  ('parmesan chees', 591),
#  ('dri basil', 585),
#  ('peel fresh ginger', 582),
#  ('mushroom', 578),
#  ('coars salt', 578),
#  ('warm water', 577),
#  ('larg egg yolk', 575),
#  ('balsam vinegar', 574),
#  ('celeri rib', 567),
#  ('cream chees', 562),
#  ('white vinegar', 554),
#  ('egg yolk', 542),
#  ('caper', 541),
#  ('ground red pepper', 538),
#  ('onion powder', 528),
#  ('dijon mustard', 513),
#  ('rice', 509),
#  ('cold water', 506),
#  ('crush red pepper flake', 505),
#  ('mirin', 503),
#  ('fresh basil leav', 502),
#  ('powder sugar', 501),
#  ('eggplant', 501),
#  ('larg egg white', 485),
#  ('cook oil', 483),
#  ('lime wedg', 482),
#  ('shred mozzarella chees', 475),
#  ('fat free less sodium chicken broth', 473),
#  ('ground pork', 473),
#  ('slice green onion', 472),
#  ('cayenn', 470),
#  ('mozzarella chees', 467),
#  ('medium shrimp', 461),
#  ('raisin', 460),
#  ('red pepper', 459),
#  ('sauc', 458),
#  ('coriand', 458),
#  ('fine chop onion', 457),
#  ('sweet potato', 455),
#  ('oyster sauc', 455),
#  ('beansprout', 454),
#  ('crush tomato', 453),
#  ('black peppercorn', 453),
#  ('egg white', 453),
#  ('chees', 447),
#  ('fresh rosemari', 442),
#  ('oregano', 440),
#  ('white pepper', 439),
#  ('cherri tomato', 436),
#  ('leek', 435),
#  ('ketchup', 432),
#  ('hoisin sauc', 429),
#  ('chop celeri', 426),
#  ('low sodium soy sauc', 425),
#  ('cheddar chees', 424),
#  ('light brown sugar', 422),
#  ('cabbag', 416),
#  ('fresh mint', 416),
#  ('larg shrimp', 414),
#  ('veget broth', 409),
#  ('crack black pepper', 408),
#  ('spring onion', 407),
#  ('peanut', 406),
#  ('chickpea', 402),
#  ('confection sugar', 395),
#  ('italian season', 395),
#  ('coriand seed', 395),
#  ('fresh oregano', 394),
#  ('lean ground beef', 392),
#  ('cook rice', 387),
#  ('bell pepper', 387),
#  ('ground pepper', 385),
#  ('low salt chicken broth', 385),
#  ('frozen pea', 383),
#  ('beef broth', 381),
#  ('activ dri yeast', 377),
#  ('cajun season', 376),
#  ('chop fresh thyme', 375),
#  ('green pepper', 373),
#  ('ground clove', 371),
#  ('cornmeal', 368),
#  ('white wine', 367),
#  ('spinach', 366),
#  ('lemongrass', 364),
#  ('ground allspic', 364),
#  ('plain yogurt', 364),
#  ('thyme', 361),
#  ('feta chees crumbl', 358),
#  ('hot water', 356),
#  ('orang', 355),
#  ('toast sesam oil', 355),
#  ('longgrain rice', 353),
#  ('parmigiano reggiano chees', 353),
#  ('white wine vinegar', 352),
#  ('fennel seed', 352),
#  ('ricotta chees', 352),
#  ('boil water', 350),
#  ('pinenut', 348),
#  ('ground white pepper', 348),
#  ('cider vinegar', 348),
#  ('light soy sauc', 347),
#  ('parsley', 345),
#  ('sake', 345),
#  ('fresh thyme', 345),
#  ('chop garlic', 345),
#  ('smoke paprika', 345),
#  ('boneless chicken skinless thigh', 343),
#  ('spaghetti', 342),
#  ('grate lemon zest', 342),
#  ('yellow corn meal', 341),
#  ('green bean', 341),
#  ('chile pepper', 340),
#  ('low sodium chicken broth', 339),
#  ('fresh ginger root', 338),
#  ('orang juic', 338),
#  ('half half', 337),
#  ('chicken thigh', 336),
#  ('sweet onion', 336),
#  ('chop parsley', 333),
#  ('shiitak', 331),
#  ('corn', 329),
#  ('basmati rice', 326),
#  ('shred monterey jack chees', 325),
#  ('tomatillo', 322),
#  ('pasta', 321),
#  ('chile', 321),
#  ('dark brown sugar', 319),
#  ('chop fresh mint', 317),
#  ('vinegar', 316),
#  ('mustard seed', 313),
#  ('dark soy sauc', 312),
#  ('vanilla', 311),
#  ('dri red wine', 309),
#  ('ghee', 307),
#  ('hot pepper sauc', 306),
#  ('bread crumb', 306),
#  ('tortilla chip', 302),
#  ('green chile', 302),
#  ('pork', 300),
#  ('serrano chile', 299),
#  ('chop tomato', 298),
#  ('sriracha', 298),
#  ('cook chicken', 296),
#  ('enchilada sauc', 295),
#  ('toast sesam seed', 294),
#  ('arborio rice', 292),
#  ('yellow bell pepper', 291),
#  ('dri bread crumb', 287),
#  ('fresh parmesan chees', 286),
#  ('fine sea salt', 285),
#  ('fresh coriand', 285),
#  ('prosciutto', 284),
#  ('garlic past', 282),
#  ('basil', 282),
#  ('radish', 282),
#  ('chop pecan', 282),
#  ('corn kernel', 280),
#  ('juic', 280),
#  ('saffron thread', 277),
#  ('long grain white rice', 277),
#  ('creol season', 276),
#  ('melt butter', 276),
#  ('beef', 273),
#  ('fresh mushroom', 272),
#  ('sweeten condens milk', 271),
#  ('taco season', 271),
#  ('romain lettuc', 270),
#  ('baguett', 270),
#  ('mango', 268),
#  ('chop green bell pepper', 268),
#  ('feta chees', 268),
#  ('okra', 268),
#  ('appl cider vinegar', 268),
#  ('andouil sausag', 267),
#  ('basil leav', 267),
#  ('unsweeten cocoa powder', 266),
#  ('pasta sauc', 266),
#  ('russet potato', 266),
#  ('shaox wine', 264),
#  ('rice noodl', 263),
#  ('mint leav', 263),
#  ('peach', 263),
#  ('veget oil cook spray', 260),
#  ('star anis', 259),
#  ('flank steak', 258),
#  ('cream', 258),
#  ('babi spinach', 257),
#  ('dri sherri', 256),
#  ('chines fivespic powder', 253),
#  ('refri bean', 250),
#  ('lemon zest', 249),
#  ('linguin', 248),
#  ('white rice', 248),
#  ('yoghurt', 247),
#  ('coriand powder', 246),
#  ('slice mushroom', 244),
#  ('fresh dill', 243),
#  ('dice onion', 242),
#  ('golden raisin', 240),
#  ('garlic salt', 240),
#  ('roast red pepper', 239),
#  ('lowfat milk', 237),
#  ('ground cardamom', 237),
#  ('nutmeg', 237),
#  ('monterey jack', 235),
#  ('grate nutmeg', 234),
#  ('greek yogurt', 233),
#  ('asparagu', 230),
#  ('fresh spinach', 230),
#  ('black oliv', 229),
#  ('marinara sauc', 229),
#  ('red wine', 229),
#  ('shorten', 229),
#  ('grape tomato', 228),
#  ('pork tenderloin', 228),
#  ('chop fresh chive', 227),
#  ('roma tomato', 227),
#  ('partskim mozzarella chees', 227),
#  ('napa cabbag', 226),
#  ('noodl', 225),
#  ('lemon wedg', 225),
#  ('banana', 224),
#  ('thai chile', 223),
#  ('ham', 222),
#  ('tortilla', 222),
#  ('cauliflow', 221),
#  ('coconut oil', 221),
#  ('rice wine', 221),
#  ('broccoli', 220),
#  ('margarin', 220),
#  ('red chili powder', 220),
#  ('strawberri', 219),
#  ('curri leav', 219),
#  ('yukon gold potato', 218),
#  ('cashew nut', 218),
#  ('tomato puré', 217),
#  ('heavi whip cream', 216),
#  ('salt ground black pepper', 215),
#  ('cilantro sprig', 215),
#  ('bacon slice', 212),
#  ('green pea', 212),
#  ('thyme sprig', 212),
#  ('lasagna noodl', 209),
#  ('fresh orang juic', 209),
#  ('evapor milk', 208),
#  ('green cabbag', 208),
#  ('bake potato', 207),
#  ('firm tofu', 207),
#  ('chive', 206),
#  ('saffron', 206),
#  ('frozen chop spinach', 206),
#  ('fennel bulb', 205),
#  ('red potato', 205),
#  ('pit kalamata oliv', 204),
#  ('cannellini bean', 203),
#  ('beer', 202),
#  ('veget', 202),
#  ('brown rice', 202),
#  ('dark sesam oil', 201),
#  ('bourbon whiskey', 199),
#  ('minc ginger', 198),
#  ('blackey pea', 196),
#  ('kalamata', 196),
#  ('water chestnut', 195),
#  ('almond', 194),
#  ('self rise flour', 193),
#  ('chipotl adobo', 193),
#  ('bread flour', 193),
#  ('pea', 193),
#  ('veget stock', 192),
#  ('french bread', 192),
#  ('unsweeten coconut milk', 191),
#  ('fresh thyme leav', 190),
#  ('broccoli floret', 190),
#  ('lettuc leav', 189),
#  ('couscou', 189),
#  ('minc onion', 189),
#  ('anchovi fillet', 189),
#  ('english cucumb', 189),
#  ('chili', 187),
#  ('slice almond', 187),
#  ('sausag', 185),
#  ('guacamol', 185),
#  ('grit', 184),
#  ('tabasco pepper sauc', 184),
#  ('snow pea', 183),
#  ('reduc sodium chicken broth', 183),
#  ('lettuc', 183),
#  ('taco season mix', 181),
#  ('grate lemon peel', 181),
#  ('cake flour', 179),
#  ('whole wheat flour', 179),
#  ('purpos unbleach flour', 179),
#  ('thai basil', 178),
#  ('penn pasta', 178),
#  ('coconut', 178),
#  ('arugula', 177),
#  ('pancetta', 177),
#  ('green oliv', 177),
#  ('shred lettuc', 175),
#  ('mussel', 175),
#  ('frozen corn', 175),
#  ('bread', 175),
#  ('stew tomato', 175),
#  ('mexican chees blend', 174),
#  ('butternut squash', 174),
#  ('almond extract', 173),
#  ('dri rosemari', 173),
#  ('hot red pepper flake', 171),
#  ('spice', 171),
#  ('pinto bean', 171),
#  ('bread crumb fresh', 170),
#  ('goat chees', 169),
#  ('dri parsley', 169),
#  ('pure vanilla extract', 169),
#  ('tomato juic', 169),
#  ('brandi', 169),
#  ('ground turkey', 168),
#  ('collard green', 167),
#  ('sliver almond', 167),
#  ('shred sharp cheddar chees', 167),
#  ('vanilla bean', 167),
#  ('provolon chees', 165),
#  ('appl', 165),
#  ('iceberg lettuc', 164),
#  ('semisweet chocol', 164),
#  ('ice water', 164),
#  ('button mushroom', 163),
#  ('mint', 163),
#  ('slice black oliv', 161),
#  ('sundri tomato', 161),
#  ('sherri vinegar', 160),
#  ('beef stock', 160),
#  ('salmon fillet', 159),
#  ('fettucin', 159),
#  ('cream tartar', 159),
#  ('kidney bean', 159),
#  ('light corn syrup', 159),
#  ('asian fish sauc', 158),
#  ('chili flake', 158),
#  ('wonton wrapper', 158),
#  ('lard', 157),
#  ('pecorino romano chees', 157),
#  ('reduc sodium soy sauc', 157),
#  ('shred chees', 157),
#  ('kale', 157),
#  ('roast peanut', 156),
#  ('shred carrot', 156),
#  ('light coconut milk', 156),
#  ('oliv', 155),
#  ('poblano chile', 155),
#  ('plain flour', 154),
#  ('sharp cheddar chees', 154),
#  ('cardamom pod', 154),
#  ('dri mustard', 152),
#  ('chicken breast halv', 152),
#  ('jasmin rice', 152),
#  ('orang zest', 152),
#  ('chipotl chile', 150),
#  ('daikon', 150),
#  ('mascarpon', 149),
#  ('grate orang', 149),
#  ('garbanzo bean', 148),
#  ('fresh tomato', 148),
#  ('polenta', 148),
#  ('chili sauc', 147),
#  ('boneless chicken breast', 146),
#  ('cook white rice', 145),
#  ('crème fraîch', 145),
#  ('panko breadcrumb', 144),
#  ('pecan', 144),
#  ('peppercorn', 144),
#  ('cream chees soften', 143),
#  ('ancho chile pepper', 143),
#  ('gochujang base', 142),
#  ('fresh tarragon', 142),
#  ('szechwan peppercorn', 142),
#  ('queso fresco', 141),
#  ('bittersweet chocol', 140),
#  ('parsley sprig', 140),
#  ('ground cayenn pepper', 139),
#  ('smoke sausag', 139),
#  ('cotija', 139),
#  ('veget shorten', 138),
#  ('cremini mushroom', 138),
#  ('season', 137),
#  ('extra firm tofu', 137),
#  ('lime zest', 137),
#  ('italian sausag', 137),
#  ('bamboo shoot', 137),
#  ('meat', 137),
#  ('ground lamb', 136),
#  ('tofu', 136),
#  ('artichok heart', 135),
#  ('salsa verd', 135),
#  ('pork shoulder', 135),
#  ('pimento', 134),
#  ('fat free milk', 134),
#  ('sweet paprika', 134),
#  ('red cabbag', 134),
#  ('chicken wing', 133),
#  ('tequila', 133),
#  ('kaffir lime leav', 133),
#  ('nonfat sour cream', 133),
#  ('dri apricot', 133),
#  ('fresh parsley leav', 132),
#  ('season salt', 131),
#  ('chines rice wine', 131),
#  ('mint sprig', 131),
#  ('garlic chili sauc', 130),
#  ('ice cube', 130),
#  ('white bread', 130),
#  ('rice flour', 130),
#  ('caster sugar', 130),
#  ('seed', 130),
#  ('allspic', 129),
#  ('chop walnut', 128),
#  ('dashi', 128),
#  ('whole peel tomato', 127),
#  ('thai red curri past', 127),
#  ('chili pepper', 126),
#  ('barbecu sauc', 126),
#  ('dri yeast', 126),
#  ('italian parsley leav', 125),
#  ('partskim ricotta chees', 125),
#  ('dri shiitak mushroom', 124),
#  ('pork belli', 124),
#  ('frozen corn kernel', 124),
#  ('chop fresh sage', 123),
#  ('ginger root', 123),
#  ('red curri past', 122),
#  ('palm sugar', 122),
#  ('chili past', 122),
#  ('peanut butter', 122),
#  ('corn oil', 121),
#  ('chilli', 121),
#  ('marsala wine', 121),
#  ('chile powder', 120),
#  ('pineappl', 120),
#  ('poblano pepper', 119),
#  ('granni smith appl', 119),
#  ('gingerroot', 119),
#  ('ginger past', 119),
#  ('bok choy', 119),
#  ('crawfish', 118),
#  ('pesto', 118),
#  ('italian bread', 118),
#  ('ice', 118),
#  ('jack chees', 118),
#  ('chicken leg', 117),
#  ('lump crab meat', 117),
#  ('greek style plain yogurt', 117),
#  ('pizza dough', 117),
#  ('yellow squash', 116),
#  ('quinoa', 116),
#  ('dark rum', 116),
#  ('vidalia onion', 115),
#  ('pork sausag', 115),
#  ('walnut', 114),
#  ('sage leav', 114),
#  ('sea scallop', 114),
#  ('turnip', 113),
#  ('fresh chive', 113),
#  ('penn', 113),
#  ('black mustard seed', 112),
#  ('kimchi', 112),
#  ('sweet chili sauc', 112),
#  ('creami peanut butter', 111),
#  ('shred cabbag', 111),
#  ('cook chicken breast', 111),
#  ('red lentil', 110),
#  ('mapl syrup', 110),
#  ('paneer', 110),
#  ('catfish fillet', 109),
#  ('chili oil', 109),
#  ('yeast', 109),
#  ('green tomato', 108),
#  ('sausag case', 108),
#  ('unflavor gelatin', 108),
#  ('thai fish sauc', 108),
#  ('mustard', 108),
#  ('rosemari sprig', 108),
#  ('crush garlic', 107),
#  ('fontina chees', 107),
#  ('rosemari', 107),
#  ('molass', 106),
#  ('frozen pastri puff sheet', 106),
#  ('curri past', 106),
#  ('whole kernel corn drain', 106),
#  ('cardamom', 106),
#  ('romano chees', 106),
#  ('dice green chili', 106),
#  ('beet', 106),
#  ('ricotta', 105),
#  ('dough', 105),
#  ('freshli grate parmesan', 105),
#  ('reducedfat sour cream', 105),
#  ('watercress', 104),
#  ('hardboil egg', 104),
#  ('serrano pepper', 104),
#  ('sugar pea', 104),
#  ('cornflour', 103),
#  ('chorizo sausag', 103),
#  ('babi spinach leav', 103),
#  ('swiss chard', 103),
#  ('dri red chile pepper', 103),
#  ('bowti pasta', 103),
#  ('marjoram', 103),
#  ('pecan halv', 102),
#  ('ground chicken', 102),
#  ('hazelnut', 100),
#  ('dri porcini mushroom', 100),
#  ('lemon grass', 100),
#  ('bean', 100),
#  ('masa harina', 100),
#  ('mexican oregano', 100),
#  ('cottag chees', 100),
#  ('slice carrot', 100),
#  ('gruyer chees', 99),
#  ('boil potato', 99),
#  ('old bay season', 98),
#  ('season bread crumb', 98),
#  ('sunflow oil', 97),
#  ('pear', 97),
#  ('broth', 97),
#  ('fresh mozzarella', 97),
#  ('green', 96),
#  ('can low sodium chicken broth', 96),
#  ('dill', 96),
#  ('nori', 96),
#  ('fresh shiitak mushroom', 96),
#  ('dri currant', 95),
#  ('red kidney bean', 95),
#  ('grate orang peel', 95),
#  ('clam', 94),
#  ('adobo sauc', 94),
#  ('chicken drumstick', 94),
#  ('cognac', 94),
#  ('orang bell pepper', 93),
#  ('leav', 93),
#  ('rice vermicelli', 93),
#  ('whole wheat tortilla', 93),
#  ('blanch almond', 93),
#  ('corn husk', 93),
#  ('vanilla ice cream', 93),
#  ('fat', 92),
#  ('prawn', 92),
#  ('cook shrimp', 92),
#  ('fresh raspberri', 92),
#  ('firmli pack brown sugar', 92),
#  ('chicken piec', 92),
#  ('clam juic', 92),
#  ('ripe oliv', 92),
#  ('blackberri', 91),
#  ('orzo', 91),
#  ('fish', 91),
#  ('angel hair', 91),
#  ('stock', 90),
#  ('tamari soy sauc', 90),
#  ('fresh green bean', 90),
#  ('elbow macaroni', 90),
#  ('leg lamb', 89),
#  ('jicama', 88),
#  ('roll', 88),
#  ('herb', 87),
#  ('amchur', 87),
#  ('lentil', 87),
#  ('quickcook grit', 86),
#  ('babi bok choy', 86),
#  ('dice celeri', 86),
#  ('green cardamom', 86),
#  ('white cornmeal', 85),
#  ('asiago', 85),
#  ('galang', 85),
#  ('mung bean sprout', 85),
#  ('egg noodl', 85),
#  ('pearl onion', 85),
#  ('squid', 85),
#  ('tamarind past', 84),
#  ('fine chop fresh parsley', 84),
#  ('frozen whole kernel corn', 84),
#  ('veget oil spray', 84),
#  ('lamb shoulder', 84),
#  ('golden brown sugar', 83),
#  ('cream chicken soup', 83),
#  ('panko', 83),
#  ('cream style corn', 83),
#  ('pineappl juic', 82),
#  ('lowfat buttermilk', 82),
#  ('pepper jack', 82),
#  ('caraway seed', 82),
#  ('raspberri', 81),
#  ('mace', 81),
#  ('skim milk', 81),
#  ('marinad', 81),
#  ('sushi rice', 81),
#  ('agav nectar', 81),
#  ('serrano chili', 81),
#  ('green cardamom pod', 80),
#  ('pizza sauc', 80),
#  ('sherri', 79),
#  ('can black bean', 79),
#  ('pico de gallo', 79),
#  ('small red potato', 79),
#  ('grapese oil', 79),
#  ('crabmeat', 79),
#  ('white bean', 79),
#  ('boneless pork shoulder', 79),
#  ('tabl salt', 79),
#  ('fat skim chicken broth', 78),
#  ('ancho powder', 78),
#  ('fillet', 78),
#  ('sweet italian sausag', 78),
#  ('lime rind', 78),
#  ('rum', 77),
#  ('homini', 77),
#  ('chicken bouillon', 77),
#  ('semisweet chocol morsel', 77),
#  ('salt butter', 77),
#  ('fennel', 77),
#  ('coconut cream', 77),
#  ('fish fillet', 77),
#  ('white sesam seed', 76),
#  ('reduc fat milk', 76),
#  ('whole clove', 76),
#  ('chee fresh mozzarella', 76),
#  ('cauliflow floret', 75),
#  ('artichok', 75),
#  ('can tomato', 75),
#  ('cook ham', 74),
#  ('instant yeast', 74),
#  ('sweeten coconut flake', 74),
#  ('grate coconut', 74),
#  ('condens milk', 74),
#  ('dri shrimp', 74),
#  ('vodka', 74),
#  ('skirt steak', 73),
#  ('ranch dress', 73),
#  ('peel tomato', 73),
#  ('miso past', 73),
#  ('superfin sugar', 73),
#  ('fenugreek seed', 73),
#  ('tilapia fillet', 73),
#  ('asafoetida', 73),
#  ('babi carrot', 72),
#  ('spinach leav', 72),
#  ('prepar horseradish', 72),
#  ('egg substitut', 72),
#  ('lemon rind', 72),
#  ('pork loin', 71),
#  ('reducedfat milk', 71),
#  ('refriger piecrust', 71),
#  ('beef rib short', 71),
#  ('white miso', 71),
#  ('lower sodium chicken broth', 71),
#  ('red food color', 71),
#  ('cilantro stem', 71),
#  ('chunki salsa', 70),
#  ('fat free yogurt', 70),
#  ('corn flour', 70),
#  ('lemon slice', 70),
#  ('cachaca', 70),
#  ('poppi seed', 70),
#  ('white homini', 69),
#  ('rice paper', 69),
#  ('tomato ketchup', 69),
#  ('salad dress', 69),
#  ('fresh curri leav', 69),
#  ('coffe', 69),
#  ('masala', 69),
#  ('sirloin steak', 69),
#  ('curri', 68),
#  ('urad dal', 68),
#  ('red bean', 68),
#  ('parsnip', 68),
#  ('chorizo', 68),
#  ('soba noodl', 68),
#  ('coars sea salt', 68),
#  ('portabello mushroom', 68),
#  ('mexican chees', 68),
#  ('hot pepper', 68),
#  ('chuck', 67),
#  ('chipotl pepper', 67),
#  ('grate chees', 67),
#  ('pork butt', 67),
#  ('curd', 67),
#  ('phyllo dough', 67),
#  ('anchovi past', 67),
#  ('bacon drip', 66),
#  ('chuck roast', 66),
#  ('konbu', 66),
#  ('rotisseri chicken', 66),
#  ('plum', 66),
#  ('italian salad dress', 66),
#  ('celeri seed', 66),
#  ('chicken liver', 65),
#  ('creol mustard', 65),
#  ('red enchilada sauc', 65),
#  ('rigatoni', 65),
#  ('ground sirloin', 65),
#  ('beef tenderloin', 65),
#  ('halibut fillet', 65),
#  ('herb de provenc', 65),
#  ('steak', 64),
#  ('pistachio', 64),
#  ('coars kosher salt', 64),
#  ('crimini mushroom', 64),
#  ('dri roast peanut', 64),
#  ('preserv lemon', 63),
#  ('taco sauc', 63),
#  ('jumbo shrimp', 63),
#  ('corn syrup', 63),
#  ('dress', 63),
#  ('mix green', 63),
#  ('shiitak mushroom cap', 63),
#  ('taco shell', 63),
#  ('dri sage', 63),
#  ('sweet pepper', 62),
#  ('lowfat sour cream', 62),
#  ('boneless pork loin', 62),
#  ('tahini', 62),
#  ('asparagu spear', 62),
#  ('condens cream chicken soup', 62),
#  ('shortgrain rice', 62),
#  ('anis', 62),
#  ('lamb', 62),
#  ('cook wine', 62),
#  ('smoke ham hock', 62),
#  ('fresh marjoram', 62),
#  ('poultri season', 62),
#  ('turkey', 62),
#  ('mash potato', 62),
#  ('littleneck clam', 62),
#  ('orang liqueur', 61),
#  ('instant espresso powder', 61),
#  ('scallion green', 61),
#  ('grate gruyèr chees', 61),
#  ('skinless chicken breast', 61),
#  ('salad', 61),
#  ('beef brisket', 61),
#  ('parmigianoreggiano chees', 61),
#  ('light mayonnais', 61),
#  ('pumpkin', 61),
#  ('prune', 61),
#  ('sweet corn', 61),
#  ('roast chicken', 61),
#  ('manchego chees', 60),
#  ('oyster', 60),
#  ('grate jack chees', 60),
#  ('semolina', 60),
#  ('season rice wine vinegar', 60),
#  ('liquid', 60),
#  ('parsley leav', 60),
#  ('bird chile', 60),
#  ('cocoa powder', 60),
#  ('ramen noodl', 60),
#  ('white mushroom', 60),
#  ('escarol', 60),
#  ('rotini', 60),
#  ('pie crust', 60),
#  ('rib', 59),
#  ('fenugreek leav', 59),
#  ('potato starch', 59),
#  ('chines cabbag', 59),
#  ('dip sauc', 59),
#  ('sausag link', 59),
#  ('fish stock', 59),
#  ('semolina flour', 59),
#  ('chop green chili', 58),
#  ('unsalt dri roast peanut', 58),
#  ('radicchio', 58),
#  ('spring roll wrapper', 58),
#  ('navel orang', 58),
#  ('beaten egg', 58),
#  ('date', 58),
#  ('mango chutney', 58),
#  ('egg roll wrapper', 57),
#  ('lower sodium soy sauc', 57),
#  ('brown mustard seed', 57),
#  ('fresh leav spinach', 57),
#  ('seawe', 57),
#  ('roast tomato', 57),
#  ('pepper flake', 57),
#  ('wine', 57),
#  ('fresh oregano leav', 57),
#  ('fresh pineappl', 56),
#  ('picant sauc', 56),
#  ('shrimp past', 56),
#  ('salad oil', 56),
#  ('thickcut bacon', 56),
#  ('swiss chees', 55),
#  ('condens cream mushroom soup', 55),
#  ('chees tortellini', 55),
#  ('savoy cabbag', 55),
#  ('light sour cream', 55),
#  ('pecorino chees', 55),
#  ('biscuit', 55),
#  ('teriyaki sauc', 55),
#  ('chicken meat', 55),
#  ('firmli pack light brown sugar', 55),
#  ('smoke salmon', 55),
#  ('salmon', 55),
#  ('salami', 54),
#  ('hamburg bun', 54),
#  ('haricot vert', 54),
#  ('tea bag', 54),
#  ('sage', 54),
#  ('anis seed', 54),
#  ('guajillo chile', 54),
#  ('italian turkey sausag', 54),
#  ('whole milk ricotta chees', 53),
#  ('boneless chicken thigh', 53),
#  ('pork loin chop', 53),
#  ('chutney', 53),
#  ('chip', 53),
#  ('japanes eggplant', 53),
#  ('reduc fat sharp cheddar chees', 53),
#  ('fusilli', 53),
#  ('pepperoni', 52),
#  ('mustard powder', 52),
#  ('celeri salt', 52),
#  ('fresh herb', 52),
#  ('pork chop', 52),
#  ('sambal ulek', 52),
#  ('anchovi', 52),
#  ('devein shrimp', 52),
#  ('dri cranberri', 51),
#  ('yellow pepper', 51),
#  ('extra sharp cheddar chees', 51),
#  ('chickpea flour', 51),
#  ('puff pastri', 51),
#  ('kasuri methi', 51),
#  ('bottl clam juic', 51),
#  ('rub sage', 51),
#  ('mustard green', 51),
#  ('edamam', 51),
#  ('malt vinegar', 51),
#  ('shred parmesan chees', 51),
#  ('clarifi butter', 51),
#  ('appl juic', 51),
#  ('lime slice', 51),
#  ('nonfat yogurt', 51),
#  ('anaheim chile', 51),
#  ('artichok heart marin', 51),
#  ('spanish chorizo', 51),
#  ('bread slice', 50),
#  ('great northern bean', 50),
#  ('turbinado', 50),
#  ('fruit', 50),
#  ('thai green curri past', 50),
#  ('capsicum', 50),
#  ('gari', 50),
#  ('nonstick spray', 50),
#  ('granul garlic', 50),
#  ('california bay leav', 50),
#  ('steam rice', 50),
#  ('crush ice', 50),
#  ('chicken bouillon granul', 50),
#  ('wild mushroom', 50),
#  ('plain lowfat yogurt', 50),
#  ('ground almond', 50),
#  ('sourdough bread', 50),
#  ('lobster', 50),
#  ('seedless cucumb', 50),
#  ('soften butter', 49),
#  ('duck', 49),
#  ('plain wholemilk yogurt', 49),
#  ('green bell pepper slice', 49),
#  ('frozen spinach', 49),
#  ('tapioca flour', 49),
#  ...]
